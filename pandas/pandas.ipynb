# %% [markdown]
# # Book Recommendations Dataset

# %% [markdown]
# This notebook uses the [Book Recommendations](https://www.kaggle.com/arashnic/book-recommendation-dataset) dataset available on Kaggle.

# %% [markdown]
# ## Imports

# %%
# TODO: Import any other modules you need
import pandas as pd

# %%
# TODO: Read Books.csv, Ratings.csv and Users.csv into similary named dataframes
Books = pd.read_csv ('Books.csv')
Ratings = pd.read_csv('Ratings.csv')
Users = pd.read_csv('Users.csv')
# Out:
# c:\Users\hester\Documents\Cohort7\cohort7_practicals\3_Introduction_to_Pandas\pd_env\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Data1 = Books.copy()
Data2= Ratings.copy()
Data3= Users.copy()

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### TODO:
# * Use the `describe` and `info` methods on each of your dataframes.
# * Check the `dtypes` for the columns in each dataframe.
# * Check for missing values in each dataframe
# * Check for any other operations commonly used during EDA and perform it here

# %%
Books=Data1.copy()

# %%
Books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
Books.tail()
# Out:
#               ISBN                                         Book-Title  \
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271355       Paula Danziger                1988
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# ...

# %%
Books.shape
# Out:
# (271360, 8)

# %%
Books.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication    object
# Publisher              object
# Image-URL-S            object
# Image-URL-M            object
# Image-URL-L            object
# dtype: object

# %%
Books.describe(include='all')
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271359               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
Books.isnull().sum().sum()
# Out:
# 6

# %%
Books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
Books[Books.eq('N.A').any(1)]
# Out:
# Empty DataFrame
# Columns: [ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher, Image-URL-S, Image-URL-M, Image-URL-L]
# Index: []

# %%
Books.dropna()
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
Books.fillna(method='ffill', inplace=True)

# %%
Books.shape
# Out:
# (271360, 8)

# %%
Books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
Ratings=Data2.copy()

# %%
Ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
Ratings.shape
# Out:
# (1149780, 3)

# %%
Ratings.dtypes
# Out:
# User-ID         int64
# ISBN           object
# Book-Rating     int64
# dtype: object

# %%
Ratings.describe(include='all')
# Out:
#              User-ID        ISBN   Book-Rating
# count   1.149780e+06     1149780  1.149780e+06
# unique           NaN      340556           NaN
# top              NaN  0971880107           NaN
# freq             NaN        2502           NaN
# mean    1.403864e+05         NaN  2.866950e+00
# std     8.056228e+04         NaN  3.854184e+00
# min     2.000000e+00         NaN  0.000000e+00
# 25%     7.034500e+04         NaN  0.000000e+00
# 50%     1.410100e+05         NaN  0.000000e+00
# 75%     2.110280e+05         NaN  7.000000e+00
# max     2.788540e+05         NaN  1.000000e+01

# %%
Ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
Ratings[Ratings.eq("N.A.").any(1)]
# Out:
# Empty DataFrame
# Columns: [User-ID, ISBN, Book-Rating]
# Index: []

# %%
Users =Data3.copy()

# %%
Users.head(10)
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN
# 5        6       santa monica, california, usa  61.0
# 6        7                 washington, dc, usa   NaN
# 7        8            timmins, ontario, canada   NaN
# 8        9          germantown, tennessee, usa   NaN
# 9       10          albacete, wisconsin, spain  26.0

# %%
Users.shape
# Out:
# (278858, 3)

# %%
Users.dtypes
# Out:
# User-ID       int64
# Location     object
# Age         float64
# dtype: object

# %%
Users['Age']= Users['Age'].astype(int)

# %%
Users[Ratings.eq("N.A.").any(1)]
# Out:
# c:\Users\hester\Documents\Cohort7\cohort7_practicals\3_Introduction_to_Pandas\pd_env\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [User-ID, Location, Age]
# Index: []

# %%
Users.describe(include='all')
# Out:
#              User-ID                         Location            Age
# count   278858.00000                           278858  168096.000000
# unique           NaN                            57339            NaN
# top              NaN  london, england, united kingdom            NaN
# freq             NaN                             2506            NaN
# mean    139429.50000                              NaN      34.751434
# std      80499.51502                              NaN      14.428097
# min          1.00000                              NaN       0.000000
# 25%      69715.25000                              NaN      24.000000
# 50%     139429.50000                              NaN      32.000000
# 75%     209143.75000                              NaN      44.000000
# max     278858.00000                              NaN     244.000000

# %%
Users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
Users.dropna()
# Out:
#         User-ID                            Location   Age
# 1             2           stockton, california, usa  18.0
# 3             4           porto, v.n.gaia, portugal  17.0
# 5             6       santa monica, california, usa  61.0
# 9            10          albacete, wisconsin, spain  26.0
# 10           11      melbourne, victoria, australia  14.0
# ...         ...                                 ...   ...
# 278848   278849         georgetown, ontario, canada  23.0
# 278850   278851                  dallas, texas, usa  33.0
# 278851   278852     brisbane, queensland, australia  32.0
# 278852   278853      stranraer, n/a, united kingdom  17.0
# 278854   278855  tacoma, washington, united kingdom  50.0
#
# [168096 rows x 3 columns]

# %%
#Fill with mean age
Users['Age'].fillna(35, inplace=True)

# %%
Users.shape
# Out:
# (278858, 3)

# %%
Users.isnull().sum()
# Out:
# User-ID     0
# Location    0
# Age         0
# dtype: int64

# %%
Users.dtypes
# Out:
# User-ID      int64
# Location    object
# Age          int32
# dtype: object

# %%
Users.describe(include='all')
# Out:
#              User-ID                         Location            Age
# count   278858.00000                           278858  278858.000000
# unique           NaN                            57339            NaN
# top              NaN  london, england, united kingdom            NaN
# freq             NaN                             2506            NaN
# mean    139429.50000                              NaN      34.850164
# std      80499.51502                              NaN      11.202663
# min          1.00000                              NaN       0.000000
# 25%      69715.25000                              NaN      29.000000
# 50%     139429.50000                              NaN      35.000000
# 75%     209143.75000                              NaN      35.000000
# max     278858.00000                              NaN     244.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
top_10 = Users.sort_values(by="Age", ascending=False).head(50)

top_10.plot(x="User-ID", y="Age", kind='bar')
# Out:
# <AxesSubplot:xlabel='User-ID'>

# %% [markdown]
# ## Fact-Finding

# %% [markdown]
# ### TODO:
# * Group the `ratings` dataframe by `User-ID` and check the `average` rating by user.
# * Group the `ratings` dataframe by `ISBN` and check the `average` rating each book has gotten.
# * Create a `Series` containing the number of books each user has read
# * Who are the top 10 most rated authors?
# * Who are the top 10 highest rated authors?

# %%
Ratings.tail(5)
# Out:
#          User-ID         ISBN  Book-Rating
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8

# %%
Ratings.shape
# Out:
# (1149780, 3)

# %%
Ratings.groupby(['User-ID']).mean()
# Out:
#          Book-Rating
# User-ID
# 2           0.000000
# 7           0.000000
# 8           2.166667
# 9           2.000000
# 10          3.000000
# ...              ...
# 278846      4.000000
# 278849      2.250000
# 278851      3.956522
# 278852      8.000000
# 278854      5.250000
#
# [105283 rows x 1 columns]

# %%
Ratings.groupby(['User-ID'])['Book-Rating'].mean()
# Out:
# User-ID
# 2         0.000000
# 7         0.000000
# 8         2.166667
# 9         2.000000
# 10        3.000000
#             ...
# 278846    4.000000
# 278849    2.250000
# 278851    3.956522
# 278852    8.000000
# 278854    5.250000
# Name: Book-Rating, Length: 105283, dtype: float64

# %%
Ratings.groupby(['ISBN'])['Book-Rating'].mean()
# Out:
# ISBN
#  0330299891    3.0
#  0375404120    1.5
#  0586045007    0.0
#  9022906116    3.5
#  9032803328    0.0
#               ...
# cn113107       0.0
# ooo7156103     7.0
# §423350229     0.0
# ´3499128624    8.0
# Ô½crosoft      7.0
# Name: Book-Rating, Length: 340556, dtype: float64

# %%
ratings_ser=pd.Series(Ratings.groupby(['User-ID'])['ISBN'].count())
ratings_ser
# Out:
# User-ID
# 2          1
# 7          1
# 8         18
# 9          3
# 10         2
#           ..
# 278846     2
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: ISBN, Length: 105283, dtype: int64

# %%
top_reader=ratings_ser.sort_values(ascending=False).head(10)
top_reader
# Out:
# User-ID
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
# 212898     4785
# 278418     4533
# 76352      3367
# 110973     3100
# 235105     3067
# Name: ISBN, dtype: int64

# %%
most=Ratings.groupby('ISBN').count()
top_10 = most.sort_values(by="Book-Rating", ascending=False).drop('User-ID',axis=1).head(11)
top_10
# Out:
#             Book-Rating
# ISBN
# 0971880107         2502
# 0316666343         1295
# 0385504209          883
# 0060928336          732
# 0312195516          723
# 044023722X          647
# 0679781587          639
# 0142001740          615
# 067976402X          614
# 0671027360          586
# 0446672211          585

# %%
high=Ratings.groupby('ISBN').max()
toop_10 = high.sort_values(by="Book-Rating", ascending=False).drop('User-ID',axis=1).head(10)
toop_10
# Out:
#             Book-Rating
# ISBN
# 0688009387           10
# 0373790341           10
# 0373790511           10
# 0373790503           10
# 037379049X           10
# 0373790481           10
# 0373790473           10
# 0373790465           10
# 0373790457           10
# 0373790449           10

# %%
mo = pd.merge(top_10,Books, on='ISBN').drop('Image-URL-L',axis=1).drop('Image-URL-S',axis=1).drop('Image-URL-M',axis=1)
mo
# Out:
#          ISBN  Book-Rating                                         Book-Title  \
# 0  0971880107         2502                                        Wild Animus
# 1  0316666343         1295                          The Lovely Bones: A Novel
# 2  0385504209          883                                  The Da Vinci Code
# 3  0060928336          732    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 4  0312195516          723                The Red Tent (Bestselling Backlist)
# 5  044023722X          647                                    A Painted House
# 6  0142001740          615                            The Secret Life of Bees
# 7  067976402X          614                             Snow Falling on Cedars
# 8  0671027360          586                                Angels &amp; Demons
# 9  0446672211          585  Where the Heart Is (Oprah's Book Club (Paperba...
#
#       Book-Author Year-Of-Publication                Publisher
# ...

# %%
hi = pd.merge(toop_10,Books, on='ISBN').drop('Image-URL-L',axis=1).drop('Image-URL-S',axis=1).drop('Image-URL-M',axis=1)
hi
# Out:
#          ISBN  Book-Rating                                         Book-Title  \
# 0  0688009387           10                                     The Blue Sword
# 1  0373790341           10  A TOUCH OF SILK - THE BACHELORS OF BEAR CREEK ...
# 2  0373790511           10                                Whisper (Blaze, 47)
# 3  0373790503           10                   His Private Pleasure (Blaze, 46)
# 4  037379049X           10                     Intimate Knowledge (Blaze, 45)
# 5  0373790481           10                     My Sexiest Mistake (Blaze, 44)
# 6  0373790473           10           Hot on Her Tail (Harlequin Blaze, No 43)
# 7  0373790465           10                          One-Night Man (Blaze, 42)
# 8  0373790457           10                   Seduced By The Enemy (Blaze, 41)
# 9  0373790449           10        Bound To Happen (WWW.Girl-Gear) (Blaze, 40)
#
#       Book-Author Year-Of-Publication    Publisher
# 0  Robin McKinley                1982  Greenwillow
# ...

# %% [markdown]
# ## Engineering
# # TODO:
# * Apply the `to_datetime` method to the `Year-of-Publication` `inplace`.
# * Use the `drop` method to drop all the `Image` columns in the `books` dataframe.
# * Split the `location` column into three columns `city`, `state`, `country`.
# * Which other `str` methods are available in pandas? Try out one or two others.
# * Merge the `ratings` and `books` dataframe into one dataframe named `books_and_ratings`
# * Merge the `books_and_ratings` dataset and the `users` dataframe into a dataframe named `user_preferences`

# %%
Books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271360 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271360 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271360 non-null  object
# dtypes: object(8)
# memory usage: 8.3+ MB

# %%
dtime= pd.to_datetime(Books['Year-Of-Publication'].astype(str), errors='coerce')
dtime
# Out:
# 0        2002-01-01
# 1        2001-01-01
# 2        1991-01-01
# 3        1999-01-01
# 4        1999-01-01
#             ...
# 271355   1988-01-01
# 271356   1991-01-01
# 271357   2004-01-01
# 271358   1996-01-01
# 271359   2000-01-01
# Name: Year-Of-Publication, Length: 271360, dtype: datetime64[ns]

# %%
Books.drop('Image-URL-L',axis=1).drop('Image-URL-S',axis=1).drop('Image-URL-M',axis=1)
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
Users[['City','State','Country']]= Users['Location'].str.split(',',2,expand=True)

# %%
Users.drop('Location',axis=1).head()
# Out:
#    User-ID  Age         City             State          Country
# 0        1   35          nyc          new york              usa
# 1        2   18     stockton        california              usa
# 2        3   35       moscow   yukon territory           russia
# 3        4   17        porto          v.n.gaia         portugal
# 4        5   35  farnborough             hants   united kingdom

# %%
Users['City'].str.capitalize()
# Out:
# 0                 Nyc
# 1            Stockton
# 2              Moscow
# 3               Porto
# 4         Farnborough
#              ...
# 278853       Portland
# 278854         Tacoma
# 278855       Brampton
# 278856      Knoxville
# 278857         Dublin
# Name: City, Length: 278858, dtype: object

# %%
Users['Country'].str.upper()
# Out:
# 0                     USA
# 1                     USA
# 2                  RUSSIA
# 3                PORTUGAL
# 4          UNITED KINGDOM
#                ...
# 278853                USA
# 278854     UNITED KINGDOM
# 278855             CANADA
# 278856                USA
# 278857            IRELAND
# Name: Country, Length: 278858, dtype: object

# %%
books_ratings=pd.merge(Ratings,Books,on='ISBN')

# %%
books_ratings.shape
# Out:
# (1031136, 10)

# %%
users_preferences=pd.merge(books_ratings,Users)
users_preferences.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1     2313  034545104X            5
# 2     2313  0812533550            9
# 3     2313  0679745580            8
# 4     2313  0060173289            9
#
#                                          Book-Title       Book-Author  \
# 0                              Flesh Tones: A Novel        M. J. Rose
# 1                              Flesh Tones: A Novel        M. J. Rose
# 2     Ender's Game (Ender Wiggins Saga (Paperback))  Orson Scott Card
# 3             In Cold Blood (Vintage International)     TRUMAN CAPOTE
# 4  Divine Secrets of the Ya-Ya Sisterhood : A Novel     Rebecca Wells
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                1986         Tor Books
# 3                1994           Vintage
# 4                1996     HarperCollins
#
#                                          Image-URL-S  \
# ...

# %%
users_preferences.shape
# Out:
# (1031136, 12)

# %%
users_preferences.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# Location               0
# Age                    0
# dtype: int64

# %% [markdown]
# ## Querying and Indexing

# %% [markdown]
# Here's a useful article:
# * [The Unreasonable Effectiveness of Method Chaining in Pandas](https://towardsdatascience.com/the-unreasonable-effectiveness-of-method-chaining-in-pandas-15c2109e3c69)

# %% [markdown]
# ### TODO:
# * Use the `query` method to return rows from the `user_preferences` dataframe where `User-ID` is equal to `276822`
# * Repeat the same operation as before but this time return rows where `ISBN` is equal to `0345260317`
# * Return rows where the `ISBN` is equal to `0345260317` and `Book-Rating` is greater than 0.
# * Repeat all the operations performed above using the `loc` method rather than `query`
# * Time the operation of both methods (See [Profiling and Timing Code](https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html)). Which is faster?
# * Use the `to_dict` method to convert the output of query to dictionary.
# * Write a function that takes in a `dataframe` and a `user_id` and returns a dictionary of rows with matching user ids. Test your function using the `user_preferences` dataframe and any user id in the data.

# %%
# %%time
x = users_preferences['User-ID']
users_preferences.query("@x==276822")
# Out:
# Wall time: 155 ms
#         User-ID        ISBN  Book-Rating  \
# 440198   276822  0060096195           10
# 440199   276822  0141310340            9
# 440200   276822  0142302198           10
# 440201   276822  0156006065            9
# 440202   276822  0375821813            9
# 440203   276822  038076041X           10
# 440204   276822  0439087597            0
# 440205   276822  0439401399            6
# 440206   276822  0689804458            8
# 440207   276822  0786812508            9
# 440208   276822  0786817070           10
# 440209   276822  0805057706           10
# 440210   276822  1551925060            8
# 440211   276822  1573248533           10
#
#                                                Book-Title  \
# 440198                                  The Boy Next Door
# 440199             Skin and Other Stories (Now in Speak!)
# 440200                                      Growing Wings
# 440201  The Riddle of Scheherazade: And Other Amazing ...
# ...

# %%
# %%time
users_preferences.query("ISBN=='0345260317'")
# Out:
# Wall time: 847 ms
#         User-ID        ISBN  Book-Rating  \
# 16845    240144  0345260317            0
# 39570    102967  0345260317            0
# 136800   184891  0345260317            0
# 178201    32195  0345260317            0
# 190074   130474  0345260317            0
# 255469    32773  0345260317            0
# 299508   152435  0345260317            7
# 344239   196160  0345260317            0
# 450645    96440  0345260317            0
# 492844   255489  0345260317            0
# 608373       67  0345260317            0
# 640739   162155  0345260317            0
# 905646    64010  0345260317            7
# 928156   203369  0345260317            0
# 928475   245988  0345260317            3
#
#                                                Book-Title Book-Author  \
# 16845   The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# 39570   The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# ...

# %%
# %%time
y = users_preferences['Book-Rating']
users_preferences.query("(ISBN=='0345260317') and (@y> 0)")
# Out:
# Wall time: 488 ms
#         User-ID        ISBN  Book-Rating  \
# 299508   152435  0345260317            7
# 905646    64010  0345260317            7
# 928475   245988  0345260317            3
#
#                                                Book-Title Book-Author  \
# 299508  The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# 905646  The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# 928475  The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
#
#        Year-Of-Publication         Publisher  \
# 299508                1978  Ballantine Books
# 905646                1978  Ballantine Books
# 928475                1978  Ballantine Books
#
#                                               Image-URL-S  \
# 299508  http://images.amazon.com/images/P/0345260317.0...
# 905646  http://images.amazon.com/images/P/0345260317.0...
# 928475  http://images.amazon.com/images/P/0345260317.0...
#
#                                               Image-URL-M  \
# ...

# %%
# %%time
users_preferences.loc[users_preferences['User-ID'] == 276822]
# Out:
# Wall time: 12 ms
#         User-ID        ISBN  Book-Rating  \
# 440198   276822  0060096195           10
# 440199   276822  0141310340            9
# 440200   276822  0142302198           10
# 440201   276822  0156006065            9
# 440202   276822  0375821813            9
# 440203   276822  038076041X           10
# 440204   276822  0439087597            0
# 440205   276822  0439401399            6
# 440206   276822  0689804458            8
# 440207   276822  0786812508            9
# 440208   276822  0786817070           10
# 440209   276822  0805057706           10
# 440210   276822  1551925060            8
# 440211   276822  1573248533           10
#
#                                                Book-Title  \
# 440198                                  The Boy Next Door
# 440199             Skin and Other Stories (Now in Speak!)
# 440200                                      Growing Wings
# 440201  The Riddle of Scheherazade: And Other Amazing ...
# ...

# %%
# %%time
users_preferences.loc[users_preferences.ISBN=='0345260317']
# Out:
# Wall time: 1.16 s
#         User-ID        ISBN  Book-Rating  \
# 16845    240144  0345260317            0
# 39570    102967  0345260317            0
# 136800   184891  0345260317            0
# 178201    32195  0345260317            0
# 190074   130474  0345260317            0
# 255469    32773  0345260317            0
# 299508   152435  0345260317            7
# 344239   196160  0345260317            0
# 450645    96440  0345260317            0
# 492844   255489  0345260317            0
# 608373       67  0345260317            0
# 640739   162155  0345260317            0
# 905646    64010  0345260317            7
# 928156   203369  0345260317            0
# 928475   245988  0345260317            3
#
#                                                Book-Title Book-Author  \
# 16845   The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# 39570   The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# ...

# %%
# %%time
users_preferences.loc[(users_preferences.ISBN=='0345260317') & (users_preferences['Book-Rating']>0)]
# Out:
# Wall time: 1.37 s
#         User-ID        ISBN  Book-Rating  \
# 299508   152435  0345260317            7
# 905646    64010  0345260317            7
# 928475   245988  0345260317            3
#
#                                                Book-Title Book-Author  \
# 299508  The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# 905646  The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
# 928475  The Dragons of Eden: Speculations on the Evolu...  Carl Sagan
#
#        Year-Of-Publication         Publisher  \
# 299508                1978  Ballantine Books
# 905646                1978  Ballantine Books
# 928475                1978  Ballantine Books
#
#                                               Image-URL-S  \
# 299508  http://images.amazon.com/images/P/0345260317.0...
# 905646  http://images.amazon.com/images/P/0345260317.0...
# 928475  http://images.amazon.com/images/P/0345260317.0...
#
#                                               Image-URL-M  \
# ...

# %%
# %%timeit
x = users_preferences['User-ID']
users_preferences.query("@x==276822")
# Out:
# 248 ms ± 23.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
users_preferences.query("ISBN=='0345260317'")
# Out:
# 575 ms ± 74.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
y = users_preferences['Book-Rating']
users_preferences.query("(ISBN=='0345260317') and (@y> 0)")
# Out:
# 659 ms ± 120 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
users_preferences.loc[users_preferences['User-ID'] == 276822]
# Out:
# 31.9 ms ± 8.74 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
users_preferences.loc[users_preferences.ISBN=='0345260317']
# Out:
# 1.23 s ± 216 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
users_preferences.loc[(users_preferences.ISBN=='0345260317') & (users_preferences['Book-Rating']>0)]
# Out:
# 1.18 s ± 179 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
x = users_preferences['User-ID']
users_preferences.query("@x==276822").to_dict()
# Out:
# {'User-ID': {440198: 276822,
#   440199: 276822,
#   440200: 276822,
#   440201: 276822,
#   440202: 276822,
#   440203: 276822,
#   440204: 276822,
#   440205: 276822,
#   440206: 276822,
#   440207: 276822,
#   440208: 276822,
#   440209: 276822,
#   440210: 276822,
#   440211: 276822},
#  'ISBN': {440198: '0060096195',
#   440199: '0141310340',
#   440200: '0142302198',
#   440201: '0156006065',
#   440202: '0375821813',
#   440203: '038076041X',
#   440204: '0439087597',
#   440205: '0439401399',
#   440206: '0689804458',
#   440207: '0786812508',
#   440208: '0786817070',
#   440209: '0805057706',
#   440210: '1551925060',
#   440211: '1573248533'},
#  'Book-Rating': {440198: 10,
#   440199: 9,
#   440200: 10,
#   440201: 9,
#   440202: 9,
#   440203: 10,
#   440204: 0,
#   440205: 6,
#   440206: 8,
#   440207: 9,
#   440208: 10,
#   440209: 10,
#   440210: 8,
#   440211: 10},
#  'Book-Title': {440198: 'The Boy Next Door',
#   440199: 'Skin and Other Stories (Now in Speak!)',
# ...

# %%
users_preferences.query("ISBN=='0345260317'").to_dict()
# Out:
# {'User-ID': {16845: 240144,
#   39570: 102967,
#   136800: 184891,
#   178201: 32195,
#   190074: 130474,
#   255469: 32773,
#   299508: 152435,
#   344239: 196160,
#   450645: 96440,
#   492844: 255489,
#   608373: 67,
#   640739: 162155,
#   905646: 64010,
#   928156: 203369,
#   928475: 245988},
#  'ISBN': {16845: '0345260317',
#   39570: '0345260317',
#   136800: '0345260317',
#   178201: '0345260317',
#   190074: '0345260317',
#   255469: '0345260317',
#   299508: '0345260317',
#   344239: '0345260317',
#   450645: '0345260317',
#   492844: '0345260317',
#   608373: '0345260317',
#   640739: '0345260317',
#   905646: '0345260317',
#   928156: '0345260317',
#   928475: '0345260317'},
#  'Book-Rating': {16845: 0,
#   39570: 0,
#   136800: 0,
#   178201: 0,
#   190074: 0,
#   255469: 0,
#   299508: 7,
#   344239: 0,
#   450645: 0,
#   492844: 0,
#   608373: 0,
#   640739: 0,
#   905646: 7,
#   928156: 0,
#   928475: 3},
# ...

# %%
y = users_preferences['Book-Rating']
users_preferences.query("(ISBN=='0345260317') and (@y> 0)").to_dict()
# Out:
# {'User-ID': {299508: 152435, 905646: 64010, 928475: 245988},
#  'ISBN': {299508: '0345260317', 905646: '0345260317', 928475: '0345260317'},
#  'Book-Rating': {299508: 7, 905646: 7, 928475: 3},
#  'Book-Title': {299508: 'The Dragons of Eden: Speculations on the Evolution of Human Intelligence',
#   905646: 'The Dragons of Eden: Speculations on the Evolution of Human Intelligence',
#   928475: 'The Dragons of Eden: Speculations on the Evolution of Human Intelligence'},
#  'Book-Author': {299508: 'Carl Sagan',
#   905646: 'Carl Sagan',
#   928475: 'Carl Sagan'},
#  'Year-Of-Publication': {299508: 1978, 905646: 1978, 928475: 1978},
#  'Publisher': {299508: 'Ballantine Books',
#   905646: 'Ballantine Books',
#   928475: 'Ballantine Books'},
#  'Image-URL-S': {299508: 'http://images.amazon.com/images/P/0345260317.01.THUMBZZZ.jpg',
#   905646: 'http://images.amazon.com/images/P/0345260317.01.THUMBZZZ.jpg',
#   928475: 'http://images.amazon.com/images/P/0345260317.01.THUMBZZZ.jpg'},
# ...

# %%
def get_rows(dframe: object,user_id: object) -> dict:
  
  rows = dframe.loc[dframe['User-ID']==user_id].to_dict()
  return rows

# %%
ac= get_rows(users_preferences,276822)
ac
# Out:
# {'User-ID': {440198: 276822,
#   440199: 276822,
#   440200: 276822,
#   440201: 276822,
#   440202: 276822,
#   440203: 276822,
#   440204: 276822,
#   440205: 276822,
#   440206: 276822,
#   440207: 276822,
#   440208: 276822,
#   440209: 276822,
#   440210: 276822,
#   440211: 276822},
#  'ISBN': {440198: '0060096195',
#   440199: '0141310340',
#   440200: '0142302198',
#   440201: '0156006065',
#   440202: '0375821813',
#   440203: '038076041X',
#   440204: '0439087597',
#   440205: '0439401399',
#   440206: '0689804458',
#   440207: '0786812508',
#   440208: '0786817070',
#   440209: '0805057706',
#   440210: '1551925060',
#   440211: '1573248533'},
#  'Book-Rating': {440198: 10,
#   440199: 9,
#   440200: 10,
#   440201: 9,
#   440202: 9,
#   440203: 10,
#   440204: 0,
#   440205: 6,
#   440206: 8,
#   440207: 9,
#   440208: 10,
#   440209: 10,
#   440210: 8,
#   440211: 10},
#  'Book-Title': {440198: 'The Boy Next Door',
#   440199: 'Skin and Other Stories (Now in Speak!)',
# ...

# %% [markdown]
# ### Hierarchical Indexing

# %% [markdown]
# Study the [Hierarchical Indexing](https://jakevdp.github.io/PythonDataScienceHandbook/03.05-hierarchical-indexing.html) chapter from Python Data Science Handbook.

# %% [markdown]
# ### TODO
# * Include 3 or 4 of your observations in the `Comments` below after exploring the dataset

# %% [markdown]
# ### Comments
# * The most rated book has the ISBN; 0971880107 and title; WILD ANIMUS was written by Rich Shapero and published in 2004 by Too far. The book was rated by 2502 Users.
# * The User with the User-ID; 11676 read the most books, the User read as much as 13602 books, is that too much?
# * The Book with the ISBN: 0679781587	has been rated by 639 Users, the 7th most rated Book, but the book does not exist in the Books Dataframe.
# * Users as old as 240 years read books in the library, I am asumming that is a fault from the data.
