# %%
import pandas as pd
from cleaning import ingest_data
from cleaning import get_sheet_data
from cleaning import SHEET_NAMES
from cleaning import clean

# %%
dict_data = ingest_data(r'\Users\DELL\Desktop\AI Saturdays Lagos\cohort7-team-Selassie\Final_Project\SELECTED FOOD (JAN_2019 - NOV 2021).csv', SHEET_NAMES)

# %%
print(SHEET_NAMES)
# Out:
# ['NATIONAL', 'ABIA', 'ABUJA', 'ANAMBRA', 'EBONYI', 'ENUGU', 'IMO', 'AKWA IBOM', 'BAYELSA', 'CROSS RIVER', 'DELTA', 'RIVERS', 'EDO', 'ADAMAWA', 'BAUCHI', 'BORNO', 'GOMBE', 'BENUE', 'TARABA', 'YOBE', 'KOGI', 'KWARA', 'NASSARAWA', 'NIGER', 'PLATEAU', 'EKITI', 'LAGOS', 'ONDO', 'OGUN_', 'OSUN', 'OYO', 'JIGAWA_', 'KADUNA_', 'KANO_', 'KATSINA', 'KEBBI_', 'ZAMFARA_', 'SOKOTO']

# %%
df_national = get_sheet_data(dict_data, 'NATIONAL')

# %%
df_national.head()
# Out:
#                              ItemLabels Unit of Measurement  \
# 0                Agric eggs medium size             1 Dozen
# 1  Agric eggs(medium size price of one)             1 Piece
# 2                Beans brown,sold loose                1 KG
# 3     Beans:white black eye. sold loose                1 KG
# 4                          Beef Bone in                1 KG
#
#    2019-01-01 00:00:00  2019-02-01 00:00:00  2019-03-01 00:00:00  \
# 0           469.858035           464.269677           459.807401
# 1            42.182421            42.233815            41.919787
# 2           382.763471           373.908351           368.073977
# 3           336.723299           338.051711           330.756108
# 4           994.204579           980.543090           980.124015
#
#    2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00  \
# 0           467.176525           464.868330           495.326018
# 1            41.945393            42.819171            39.307768
# ...

# %%
df_abia = get_sheet_data(dict_data, 'ABIA')

# %%
df_abia.head(2)
# Out:
#                    ItemLabels Unit of Measurement  2019-01-01 00:00:00  \
# 0      Agric eggs medium size             1 Dozen            482.50000
# 1  Agric eggs medium size (1)             1 Piece             46.35621
#
#    2019-02-01 00:00:00  2019-03-01 00:00:00  2019-04-01 00:00:00  \
# 0           489.523810           496.923077           490.947368
# 1            48.461538            49.333333            46.090909
#
#    2019-05-01 00:00:00  2019-06-01 00:00:00  2019-07-01 00:00:00  \
# 0           501.470769           525.714286           510.000000
# 1            47.560498            40.000000            36.366667
#
#    2019-08-01 00:00:00  ...  2021-05-01 00:00:00  2021-06-01 00:00:00  \
# 0               480.75  ...           650.842105           680.888889
# 1                42.35  ...            58.025148            58.955556
#
#    2021-07-01 00:00:00  2021-08-01 00:00:00  2021-09-01 00:00:00  \
# 0           688.333333           690.129412           695.588235
# ...

# %%
df_abia["Item and Size"] = df_abia["ItemLabels"] + df_abia["Unit of Measurement"]

# %%
df_abia['Item and Size'].head()
# Out:
# 0            Agric eggs medium size1 Dozen
# 1        Agric eggs medium size (1)1 Piece
# 2               Beans brown,sold loose1 KG
# 3    Beans:white black eye. sold loose1 KG
# 4                         Beef Bone in1 KG
# Name: Item and Size, dtype: object

# %%
df_abia.head(2)
# Out:
#                    ItemLabels Unit of Measurement  2019-01-01 00:00:00  \
# 0      Agric eggs medium size             1 Dozen            482.50000
# 1  Agric eggs medium size (1)             1 Piece             46.35621
#
#    2019-02-01 00:00:00  2019-03-01 00:00:00  2019-04-01 00:00:00  \
# 0           489.523810           496.923077           490.947368
# 1            48.461538            49.333333            46.090909
#
#    2019-05-01 00:00:00  2019-06-01 00:00:00  2019-07-01 00:00:00  \
# 0           501.470769           525.714286           510.000000
# 1            47.560498            40.000000            36.366667
#
#    2019-08-01 00:00:00  ...  2021-06-01 00:00:00  2021-07-01 00:00:00  \
# 0               480.75  ...           680.888889           688.333333
# 1                42.35  ...            58.955556            59.785714
#
#    2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 0           690.129412           695.588235           680.909091
# ...

# %%
df_abia.drop(['ItemLabels', 'Unit of Measurement'], axis='columns', inplace=True)

# %%
df_abia.head()
# Out:
#    2019-01-01 00:00:00  2019-02-01 00:00:00  2019-03-01 00:00:00  \
# 0           482.500000           489.523810           496.923077
# 1            46.356210            48.461538            49.333333
# 2           489.583333           497.619048           475.000000
# 3           482.770270           486.000000           462.142857
# 4           987.675156           898.166029           903.454893
#
#    2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00  \
# 0           490.947368           501.470769           525.714286
# 1            46.090909            47.560498            40.000000
# 2           480.519481           509.882000           480.935829
# 3           464.422078           472.460333           453.437500
# 4           976.537555           988.642500           992.450567
#
#    2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00  \
# 0           510.000000               480.75           490.000000
# ...

# %%
transposed_df = df_abia.set_index("Item and Size").T

# %%
transposed_df.head(2)
# Out:
# Item and Size        Agric eggs medium size1 Dozen  \
# 2019-01-01 00:00:00                      482.50000
# 2019-02-01 00:00:00                      489.52381
#
# Item and Size        Agric eggs medium size (1)1 Piece  \
# 2019-01-01 00:00:00                          46.356210
# 2019-02-01 00:00:00                          48.461538
#
# Item and Size        Beans brown,sold loose1 KG  \
# 2019-01-01 00:00:00                  489.583333
# 2019-02-01 00:00:00                  497.619048
#
# Item and Size        Beans:white black eye. sold loose1 KG  Beef Bone in1 KG  \
# 2019-01-01 00:00:00                              482.77027        987.675156
# 2019-02-01 00:00:00                              486.00000        898.166029
#
# Item and Size        Beef,boneless1 KG  Bread sliced (500g)1 Loaf  \
# 2019-01-01 00:00:00        1421.607346                 372.000000
# 2019-02-01 00:00:00        1433.878869                 392.857143
#
# ...

# %%
transposed_df.columns
# Out:
# Index(['Agric eggs medium size1 Dozen', 'Agric eggs medium size (1)1 Piece',
#        'Beans brown,sold loose1 KG', 'Beans:white black eye. sold loose1 KG',
#        'Beef Bone in1 KG', 'Beef,boneless1 KG', 'Bread sliced (500g)1 Loaf',
#        'Bread unsliced (500g)1 Loaf', 'Broken Rice (Ofada)1 KG',
#        'Chicken Feet1 KG', 'Chicken Wings1 KG',
#        'Evaporated tinned milk carnation 170g',
#        'Evaporated tinned milk(peak)170g', 'Frozen chicken1 Unit',
#        'Gari white,sold loose1 KG', 'Gari yellow,sold loose1 KG',
#        'Mudfish (aro) fresh1 KG', 'Mudfish : dried1 KG', 'Onion bulb1 KG',
#        'Rice agric sold loose1 KG', 'Rice local sold loose1 KG',
#        'Rice Medium Grained1 KG', 'Rice,imported high quality sold loose1 KG',
#        'Tomato1 KG', 'Yam tuber1 KG', 'Dried Fish Sardine1 KG',
#        'Iced Sardine1 KG', 'Irish potato1 KG', 'Sweet potato1 KG',
#        'Tilapia fish (epiya) fresh1 KG', 'Titus:frozen1 KG',
# ...

# %%
transposed_df.index
# Out:
# Index([2019-01-01 00:00:00, 2019-02-01 00:00:00, 2019-03-01 00:00:00,
#        2019-04-01 00:00:00, 2019-05-01 00:00:00, 2019-06-01 00:00:00,
#        2019-07-01 00:00:00, 2019-08-01 00:00:00, 2019-09-01 00:00:00,
#        2019-10-01 00:00:00, 2019-11-01 00:00:00, 2019-12-01 00:00:00,
#        2020-01-01 00:00:00, 2020-02-01 00:00:00, 2020-03-01 00:00:00,
#        2020-04-01 00:00:00, 2020-05-01 00:00:00, 2020-06-01 00:00:00,
#        2020-07-01 00:00:00, 2020-08-01 00:00:00, 2020-09-01 00:00:00,
#        2020-10-01 00:00:00, 2020-11-01 00:00:00, 2020-12-01 00:00:00,
#        2021-01-01 00:00:00, 2021-02-01 00:00:00, 2021-03-01 00:00:00,
#        2021-04-01 00:00:00, 2021-05-01 00:00:00, 2021-06-01 00:00:00,
#        2021-07-01 00:00:00, 2021-08-01 00:00:00, 2021-09-01 00:00:00,
#        2021-10-01 00:00:00, 2021-11-01 00:00:00,       'Unnamed: 37',
#              'Unnamed: 38',       'Unnamed: 39'],
#       dtype='object')

# %%
df_sokoto = get_sheet_data(dict_data, 'SOKOTO')

# %%
df_sokoto.head(2)
# Out:
#                              ItemLabels Unit of Measurement  \
# 0                Agric eggs medium size             1 Dozen
# 1  Agric eggs(medium size price of one)             1 Piece
#
#    2019-01-01 00:00:00  2019-02-01 00:00:00  2019-03-01 00:00:00  \
# 0           475.714286           451.428571           441.428571
# 1            40.000000            40.000000            39.285714
#
#    2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00  \
# 0           475.714286           445.142857           495.714286
# 1            40.000000            40.360000            40.000000
#
#    2019-07-01 00:00:00  2019-08-01 00:00:00  ...  2021-06-01 00:00:00  \
# 0           475.428571                464.0  ...              605.000
# 1            40.214000                 40.0  ...               51.625
#
#    2021-07-01 00:00:00  2021-08-01 00:00:00  2021-09-01 00:00:00  \
# 0           682.727273           687.500000           676.153846
# ...

# %%
sokoto = clean(df_sokoto)

# %%
sokoto
# Out:
# Item and Size        Agric eggs medium size1 Dozen  \
# 2019-01-01 00:00:00                     475.714286
# 2019-02-01 00:00:00                     451.428571
# 2019-03-01 00:00:00                     441.428571
# 2019-04-01 00:00:00                     475.714286
# 2019-05-01 00:00:00                     445.142857
# 2019-06-01 00:00:00                     495.714286
# 2019-07-01 00:00:00                     475.428571
# 2019-08-01 00:00:00                     464.000000
# 2019-09-01 00:00:00                     475.000000
# 2019-10-01 00:00:00                     480.000000
# 2019-11-01 00:00:00                     461.250000
# 2019-12-01 00:00:00                     450.000000
# 2020-01-01 00:00:00                     452.360000
# 2020-02-01 00:00:00                     444.444444
# 2020-03-01 00:00:00                     455.294118
# 2020-04-01 00:00:00                     480.000000
# 2020-05-01 00:00:00                     480.000000
# ...

# %%
sokoto.tail()
# Out:
# Item and Size        Agric eggs medium size1 Dozen  \
# 2021-07-01 00:00:00                     682.727273
# 2021-08-01 00:00:00                     687.500000
# 2021-09-01 00:00:00                     676.153846
# 2021-10-01 00:00:00                     660.000000
# 2021-11-01 00:00:00                     668.000000
#
# Item and Size        Agric eggs(medium size price of one)1 Piece  \
# 2021-07-01 00:00:00                                    57.545455
# 2021-08-01 00:00:00                                    57.117647
# 2021-09-01 00:00:00                                    57.307692
# 2021-10-01 00:00:00                                    58.000000
# 2021-11-01 00:00:00                                    60.000000
#
# Item and Size        Beans brown,sold loose1 KG  \
# 2021-07-01 00:00:00                  430.769231
# 2021-08-01 00:00:00                  485.782821
# 2021-09-01 00:00:00                  460.615272
# 2021-10-01 00:00:00                  445.129089
# ...

# %%
sokoto.index
# Out:
# Index([2019-01-01 00:00:00, 2019-02-01 00:00:00, 2019-03-01 00:00:00,
#        2019-04-01 00:00:00, 2019-05-01 00:00:00, 2019-06-01 00:00:00,
#        2019-07-01 00:00:00, 2019-08-01 00:00:00, 2019-09-01 00:00:00,
#        2019-10-01 00:00:00, 2019-11-01 00:00:00, 2019-12-01 00:00:00,
#        2020-01-01 00:00:00, 2020-02-01 00:00:00, 2020-03-01 00:00:00,
#        2020-04-01 00:00:00, 2020-05-01 00:00:00, 2020-06-01 00:00:00,
#        2020-07-01 00:00:00, 2020-08-01 00:00:00, 2020-09-01 00:00:00,
#        2020-10-01 00:00:00, 2020-11-01 00:00:00, 2020-12-01 00:00:00,
#        2021-01-01 00:00:00, 2021-02-01 00:00:00, 2021-03-01 00:00:00,
#        2021-04-01 00:00:00, 2021-05-01 00:00:00, 2021-06-01 00:00:00,
#        2021-07-01 00:00:00, 2021-08-01 00:00:00, 2021-09-01 00:00:00,
#        2021-10-01 00:00:00, 2021-11-01 00:00:00],
#       dtype='object')

# %%
sokoto.index = pd.to_datetime(sokoto.index)

# %%
sokoto
# Out:
# Item and Size  Agric eggs medium size1 Dozen  \
# 2019-01-01                        475.714286
# 2019-02-01                        451.428571
# 2019-03-01                        441.428571
# 2019-04-01                        475.714286
# 2019-05-01                        445.142857
# 2019-06-01                        495.714286
# 2019-07-01                        475.428571
# 2019-08-01                        464.000000
# 2019-09-01                        475.000000
# 2019-10-01                        480.000000
# 2019-11-01                        461.250000
# 2019-12-01                        450.000000
# 2020-01-01                        452.360000
# 2020-02-01                        444.444444
# 2020-03-01                        455.294118
# 2020-04-01                        480.000000
# 2020-05-01                        480.000000
# 2020-06-01                        476.428571
# 2020-07-01                        480.000000
# 2020-08-01                        487.058824
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10, 5))

plt.scatter(sokoto.index, sokoto['Agric eggs medium size1 Dozen'], marker ='s', c = 'yellow')
plt.scatter(sokoto.index, sokoto['Agric eggs(medium size price of one)1 Piece'], marker = '*', c = 'pink')
plt.scatter(sokoto.index, sokoto['Beans brown,sold loose1 KG'], marker = 'X', c = 'brown')
plt.scatter(sokoto.index, sokoto['Beans:white black eye. sold loose1 KG'], marker = '^', c = 'blue')
plt.scatter(sokoto.index, sokoto['Beef Bone in1 KG'], marker = 'P', c = 'red')
plt.scatter(sokoto.index, sokoto['Beef,boneless1 KG'], c = 'green')
plt.scatter(sokoto.index, sokoto['Bread sliced 500g1 Loaf'], c = 'orange')
plt.scatter(sokoto.index, sokoto['Bread unsliced 500g1 Loaf'], c = 'cyan')
plt.scatter(sokoto.index, sokoto['Broken Rice (Ofada)1 KG'], c = 'magenta')
plt.scatter(sokoto.index, sokoto['Chicken Feet1 KG'], c = 'black')

plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Food prices from 2019-2022')
# Out:
# Text(0.5, 1.0, 'Food prices from 2019-2022')

# %%
import plotly.express as px

# Plot an interactive chart of the clusters with reference to principal components 
fig = px.scatter(sokoto, x =  sokoto.index, y = sokoto.columns)
fig.show()

# %%
'''
def visualize_data(clean_df):
    clean_df.index = pd.to_datetime(clean_df.index, errors = 'raise')
    df_plot = plt.scatter(clean_df.index, clean_df.columns, marker ='s', c = 'yellow')
    return df_plot
'''
# Out:
# "\ndef visualize_data(clean_df):\n    clean_df.index = pd.to_datetime(clean_df.index, errors = 'raise')\n    df_plot = plt.scatter(clean_df.index, clean_df.columns, marker ='s', c = 'yellow')\n    return df_plot\n"

# %%
from matplotlib import pyplot
from matplotlib.pyplot import figure

# %%
sokoto.plot()
pyplot.show()
pyplot.figure(figsize=(10,20))

# %%
series= sokoto[['Agric eggs medium size1 Dozen', 'Beef Bone in1 KG']]
series.plot()
pyplot.show()
figure(figsize=(20, 18))

# %%
series.head()
# Out:
# Item and Size  Agric eggs medium size1 Dozen  Beef Bone in1 KG
# 2019-01-01                        475.714286       1080.000000
# 2019-02-01                        451.428571        977.666667
# 2019-03-01                        441.428571        971.428571
# 2019-04-01                        475.714286       1030.952381
# 2019-05-01                        445.142857        998.952857

# %%
sokoto.reset_index(inplace= True)

# %%
sokoto.rename(columns={'index':'Date'}, inplace= True)

# %%
sokoto
# Out:
# Item and Size       Date  Agric eggs medium size1 Dozen  \
# 0             2019-01-01                     475.714286
# 1             2019-02-01                     451.428571
# 2             2019-03-01                     441.428571
# 3             2019-04-01                     475.714286
# 4             2019-05-01                     445.142857
# 5             2019-06-01                     495.714286
# 6             2019-07-01                     475.428571
# 7             2019-08-01                     464.000000
# 8             2019-09-01                     475.000000
# 9             2019-10-01                     480.000000
# 10            2019-11-01                     461.250000
# 11            2019-12-01                     450.000000
# 12            2020-01-01                     452.360000
# 13            2020-02-01                     444.444444
# 14            2020-03-01                     455.294118
# 15            2020-04-01                     480.000000
# ...

# %%
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(series)
pyplot.show()

# %%
sokoto_new=sokoto.melt(id_vars=['Date'], var_name="Food_items", value_name="Food_prices")

# %%
sokoto_new.head()
# Out:
#         Date                     Food_items  Food_prices
# 0 2019-01-01  Agric eggs medium size1 Dozen   475.714286
# 1 2019-02-01  Agric eggs medium size1 Dozen   451.428571
# 2 2019-03-01  Agric eggs medium size1 Dozen   441.428571
# 3 2019-04-01  Agric eggs medium size1 Dozen   475.714286
# 4 2019-05-01  Agric eggs medium size1 Dozen   445.142857
